# %%
import pandas as pd
import csv
import json

# %%
school_data = pd.read_csv("data/school_scores_2017_18.csv")

# %%
school_data.head()
# Out:
#    COUNTY_CODE COUNTY_NAME  DISTRICT_CODE  DISTRICT_NAME  SCHOOL_CODE  \
# 0            1    ATLANTIC             10   ABSECON CITY           50
# 1            1    ATLANTIC             10   ABSECON CITY           60
# 2            1    ATLANTIC            110  ATLANTIC CITY           10
# 3            1    ATLANTIC            110  ATLANTIC CITY           30
# 4            1    ATLANTIC            110  ATLANTIC CITY           50
#
#                  SCHOOL_NAME GRADESPAN PRINCIPAL_NAME               ADDRESS  \
# 0             EMMA C ATTALES     05-08      MR. BURNS     800 IRELAN AVENUE
# 1             H ASHTON MARSH     PK-04   MR. GIARDINA        800 IRELAN AVE
# 2  ATLANTIC CITY HIGH SCHOOL     09-12        MS. GIL  1400 N ALBANY AVENUE
# 3    SOVEREIGN AVENUE SCHOOL     PK-08     MS. PEYTON    3205 ARCTIC AVENUE
# 4     CHELSEA HEIGHTS SCHOOL     PK-08      MR. FLOOD  4101  FILBERT AVENUE
#
#                 CITY_STATE_ZIP  ... CA_MetAverage Targeted_ConsUnderPerf  \
# ...
